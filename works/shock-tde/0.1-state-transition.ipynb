# %%
# %load_ext autoreload
# %autoreload 2
import matplotlib.pyplot as plt
import numpy as np
import unyt as u

import dev
import richio

# %%
snapnums, paths = dev.DATAPATHS
# Out:
# Failed to start the Kernel.
#
# Unable to start Kernel 'richanalysis (Python 3.13.7)' due to a timeout waiting for the ports to get used.
#
# View Jupyter <a href='command:jupyter.viewOutput'>log</a> for further details.

# %%
snapnums =
