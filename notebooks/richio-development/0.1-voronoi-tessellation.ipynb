# %% [markdown]
# # Use a proper voronoi tessellation over nearest neighbor

# %%
# %load_ext autoreload
# %autoreload 2

import os

from scipy.spatial import Voronoi, voronoi_plot_2d
import numpy as np
import matplotlib.pyplot as plt

import richio, nb, dev
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
snap_dir = "/home/hey4/rich_tde/data/raw/SedovDissipationGrad"
snap = richio.load(os.path.join(snap_dir, "sedov_100.h5"))

# %%
points = np.stack([snap.X, snap.Y, snap.Z], axis=-1)

# %%
vor = Voronoi(points)

# %% [markdown]
# ## Test speed and scalability to TDE

# %%
snap = richio.load(
    "/home/hey4/rich_tde/data/external/R0.47M0.5BH10000beta1S60Compton/snap_full_361.h5"
)
