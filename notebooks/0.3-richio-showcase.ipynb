# %%
# %load_ext autoreload
# %autoreload 2

import numpy as np
import h5py
import unyt as u

import richio
import nb, dev

# %% [markdown]
# ## Read HDF5 files

# %%
hdf5_path = '/data1/projects/pi-rossiem/TDE_data/R0.47M0.5BH10000beta1S60n1.5ComptonMG/snap_429/snap_429.h5'
snap = richio.load(hdf5_path)
type(snap)
# Out:
# richio.data.SnapshotH5

# %%
print(snap.keys())
# Out:
# ['Box', 'CMx', 'CMy', 'CMz', 'Cycle', 'Density', 'Dissipation', 'DpDx', 'DpDy', 'DpDz', 'DrhoDx', 'DrhoDy', 'DrhoDz', 'DsieDx', 'DsieDy', 'DsieDz', 'Eg_0', 'Eg_1', 'Eg_2', 'Eg_3', 'Eg_4', 'Eg_5', 'Eg_6', 'Eg_7', 'Eg_8', 'Eg_9', 'Erad', 'ID', 'InternalEnergy', 'Pressure', 'Temperature', 'Time', 'Volume', 'Vx', 'Vy', 'Vz', 'X', 'Y', 'Z', 'divV', 'tracers/Entropy', 'tracers/Star']

# %% [markdown]
# ## Read npy directory

# %%
dir_path = '/data1/projects/pi-rossiem/TDE_data/R0.47M0.5BH10000beta1S60n1.5ComptonHiResNewAMR/snap_45'
snap_npy = richio.load(dir_path)
type(snap_npy)
# Out:
# richio.data.SnapshotNPY

# %%
print(snap_npy.keys())
# Out:
# ['CMx', 'CMy', 'CMz', 'Den', 'Diss', 'DivV', 'DpDx', 'DpDy', 'DpDz', 'Entropy', 'IE', 'Mass', 'P', 'Rad', 'Star', 'T', 'Vol', 'Vx', 'Vy', 'Vz', 'box', 'tfb']

# %% [markdown]
# ## Accessing data

# %% [markdown]
# Richio only stores two metadata to minimise ram usage. Other information are read from the dataset.

# %%
# Basic info
print(snap.snapnum)
print(snap.path)
# Out:
# 429
# /data1/projects/pi-rossiem/TDE_data/R0.47M0.5BH10000beta1S60n1.5ComptonMG/snap_429/snap_429.h5

# %% [markdown]
# ### Unit

# %%
density = snap.density
print(density)
# Out:
# [1.00002616e-20 9.99990230e-21 9.99997206e-21 ... 1.00072158e-20
#  9.99658544e-21 9.99789041e-21] code_mass/code_length**3

# %%
density = density.in_cgs()
print(density)
# Out:
# [5.83105635e-20 5.83084682e-20 5.83088750e-20 ... 5.83511126e-20
#  5.82891279e-20 5.82967371e-20] g/cm**3

# %%
density = density.in_base('rich')
print(density)
# Out:
# [1.00002616e-20 9.99990230e-21 9.99997206e-21 ... 1.00072158e-20
#  9.99658544e-21 9.99789041e-21] code_mass/code_length**3

# %%
# Meta data
print(snap.time)
print(snap.box)
# Out:
# [314.90405245] code_time
# [-67212.44623327 -81173.43705695 -81397.57821301  73870.11453231
#   92011.31178429  95264.51034046] code_length

# %%
# Dimension checking
from unyt.dimensions import _has_dimensions, length, energy, time, volume
print(_has_dimensions(snap.box, length))
print(_has_dimensions(snap.dissipation, energy / time / volume))
# Out:
# True
# True

# %% [markdown]
# ### Aliases
# Richio supports many aliases, so you would have a easy time switching from other softwares such as [swiftsimio](https://swiftsimio.readthedocs.io/en/latest/) or [yt](https://yt-project.org).

# %%
snap.info(unit_system='cgs', show_aliases=True)
# Out:
# ──────────────────────────────────────────── RICH Snapshot Information ────────────────────────────────────────────
#  Path             /data1/projects/pi-rossiem/TDE_data/R0.47M0.5BH10000beta1S60n1.5ComptonMG/snap_429/snap_429.h5
#  Snapshot number  429
#  Time             504791.1960817355 s
#  Box size         [-4.70487124e+15 -5.68214059e+15 -5.69783047e+15  5.17090802e+15
#                     6.44079182e+15  6.66851572e+15] cm
#  Cycle            215481.0 dimensionless
#  Number of cells  18,832,192
#  Number of ranks  256
#                                       Available Fields  (unit system: CGS)
# ┏━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┓
# ┃ Field           ┃ Unit                              ┃ Aliases                                                 ┃
# ┡━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┩
# │ Box             │ 70000000000.0 cm                  │ box_size, box, boxsize                                  │
# │ CMx             │ 70000000000.0 cm                  │ cm_x, center_of_mass_x                                  │
# │ CMy             │ 70000000000.0 cm                  │ cm_y, center_of_mass_y                                  │
# │ CMz             │ 70000000000.0 cm                  │ cm_z, center_of_mass_z                                  │
# │ Cycle           │ 1.0 dimensionless                 │ cycle, step, iteration                                  │
# │ Density         │ 5.830903790087464 g/cm**3         │ density, densitites, Den, rho                           │
# │ Dissipation     │ 6936356222216.378 g/(cm*s**3)     │ dissipation, Diss, dissipation_rate                     │
# │ DpDx            │ 158842.5574887551 g/(cm**2*s**2)  │ pressure_gradient_x, grad_p_x, dp_dx                    │
# │ DpDy            │ 158842.5574887551 g/(cm**2*s**2)  │ pressure_gradient_y, grad_p_y, dp_dy                    │
# │ DpDz            │ 158842.5574887551 g/(cm**2*s**2)  │ pressure_gradient_z, grad_p_z, dp_dz                    │
# │ DrhoDx          │ 8.329862557267806e-11 g/cm**4     │ density_gradient_x, grad_rho_x, drho_dx                 │
# │ DrhoDy          │ 8.329862557267806e-11 g/cm**4     │ density_gradient_y, grad_rho_y, drho_dy                 │
# │ DrhoDz          │ 8.329862557267806e-11 g/cm**4     │ density_gradient_z, grad_rho_z, drho_dz                 │
# │ DsieDx          │ 1189585092110.109 cm**2/s**3      │ sie_gradient_x, grad_sie_x, dsie_dx                     │
# │ DsieDy          │ 1189585092110.109 cm**2/s**3      │ sie_gradient_y, grad_sie_y, dsie_dy                     │
# │ DsieDz          │ 1189585092110.109 cm**2/s**3      │ sie_gradient_z, grad_sie_z, dsie_dz                     │
# │ Eg_0            │ (unused)                          │ eg_0                                                    │
# │ Eg_1            │ ?                                 │ -                                                       │
# │ Eg_2            │ ?                                 │ -                                                       │
# │ Eg_3            │ ?                                 │ -                                                       │
# │ Eg_4            │ ?                                 │ -                                                       │
# │ Eg_5            │ ?                                 │ -                                                       │
# │ Eg_6            │ ?                                 │ -                                                       │
# │ Eg_7            │ ?                                 │ -                                                       │
# │ Eg_8            │ ?                                 │ -                                                       │
# │ Eg_9            │ ?                                 │ -                                                       │
# │ Erad            │ 1906904902652504.8 erg/g          │ radiation_energy, Rad, E_rad, Erad                      │
# │ ID              │ 1.0 dimensionless                 │ particle_id, id, ids, particle_ids                      │
# │ InternalEnergy  │ 1906904902652504.8 erg/g          │ internal_energy, IE, specific_internal_energy, sie      │
# │ Pressure        │ 1.1118979024212856e+16 dyn/cm**2  │ pressure, P                                             │
# │ Temperature     │ 1.0 K                             │ temperature, T, temp                                    │
# │ Time            │ 1603.0 s                          │ time, t, tfb, simulation_time, current_time             │
# │ Volume          │ 3.4299999999999995e+32 cm**3      │ volume, Vol, volumes                                    │
# │ Vx              │ 43668122.27074236 cm/s            │ velocity_x, vx, vel_x, particle_velocity_x              │
# │ Vy              │ 43668122.27074236 cm/s            │ velocity_y, vy, vel_y, particle_velocity_y              │
# │ Vz              │ 43668122.27074236 cm/s            │ velocity_z, vz, vel_z, particle_velocity_z              │
# │ X               │ 70000000000.0 cm                  │ position_x, pos_x, x, particle_position_x               │
# │ Y               │ 70000000000.0 cm                  │ position_y, pos_y, y, particle_position_y               │
# │ Z               │ 70000000000.0 cm                  │ position_z, pos_z, z, particle_position_z               │
# │ divV            │ 0.0006238303181534623 1/s         │ velocity_divergence, DivV, div_v, divergence            │
# │ tracers/Entropy │ 1906904902652504.5 cm**2/(K*s**2) │ entropy, Entropy, S                                     │
# │ tracers/Star    │ 1.0 dimensionless                 │ star_fraction, Star, star, star_ratio, stellar_fraction │
# └─────────────────┴───────────────────────────────────┴─────────────────────────────────────────────────────────┘
# Total: 42 fields
# ───────────────────────────────────────────────────────────────────────────────────────────────────────────────────

# %% [markdown]
# Access rich unit system by

# %%
richio.units.system
# Out:
# rich Unit System
#  Base Units:
#   length: code_length
#   mass: code_mass
#   time: code_time
#   temperature: K
#   angle: rad
#   current_mks: A
#   luminous_intensity: cd
#   logarithmic: Np
#  Other Units:

# %% [markdown]
# or equivalently from `unyt`, the rich unit system is registered when you import `richio`

# %%
import unyt as u
u.unit_systems.unit_system_registry['rich']
# Out:
# rich Unit System
#  Base Units:
#   length: code_length
#   mass: code_mass
#   time: code_time
#   temperature: K
#   angle: rad
#   current_mks: A
#   luminous_intensity: cd
#   logarithmic: Np
#  Other Units:

# %% [markdown]
# ### Fancy indexing
# Richio support full numpy [slicing and striding](https://numpy.org/doc/stable/user/basics.indexing.html).

# %%
density_subsample = snap.density[::1234]
print(density_subsample.shape)

density_subsample = snap['density', 1000:30000:100]
print(density_subsample.shape)
# Out:
# (15262,)
# (290,)

# %% [markdown]
# ## RICH specific masking

# %% [markdown]
# Richio provides necessary maskings in data processing, two complimentary masks to remove floor and spurious gases. Usually star_mask alone can filter out all the gases.

# %%
star_mask = snap.mask_star_ratio()
print(np.sum(star_mask), len(star_mask))

density_mask = snap.mask_density()
print(np.sum(density_mask), len(density_mask))

mask = star_mask & density_mask
print(np.sum(mask), len(mask))
# Out:
# 18582151 18832192
# 18580601 18832192
# 18580601 18832192

# %%
density = snap.density
density_masked = density[mask]
print(len(density_masked))
print(density_masked)
# Out:
# 18580601
# [1.57520040e-19 2.37789397e-19 3.88563073e-19 ... 1.43013837e-19
#  1.81199076e-19 1.23109857e-19] code_mass/code_length**3

# %% [markdown]
# ## Plotting
# RICHIO currently offers two types of plots, slice and projection plots.

# %%
import matplotlib.pyplot as plt

# %% [markdown]
# ### Quick peek: A slice through xy midplane

# %%
# returns the axes, quadmesh object returned from pcolormesh, and the 2D
# unyt_array data that is plotted. With the quadmesh object you can change
# colorbar and stuff without replotting, very handy.
ax, im, data = snap.plots.peek()
plt.show()

# %% [markdown]
# ### Slicing plot

# %%
ax, im, sliced_data = snap.plots.slice(
        data='density',
        X='X', Y='Y', Z='Z',
        res=512, plane='xy',
        slice_coord=0,
        box_size=[-2000, -1000, 800, 800]
    )
plt.show()

# %% [markdown]
# ### Projection plot

# %%
ax, im, projected_data = snap.plots.projection(data='density', 
    X='CMx', Y='CMy', Z='CMz', res=512,
    box_size=[-2000, -1000, -1000, 800, 800, 1000]
    )
plt.show()
