# %% [markdown]
# # Use a proper voronoi tessellation over nearest neighbor

# %%
# %load_ext autoreload
# %autoreload 2

import os

from scipy.spatial import Voronoi, voronoi_plot_2d
import numpy as np
import matplotlib.pyplot as plt

import richio, nb, dev
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
snap_dir = '/home/hey4/rich_tde/data/raw/SedovDissipationGrad'
snap = richio.load(os.path.join(snap_dir, 'sedov_100.h5'))

# %%
points = np.stack([snap.X, snap.Y, snap.Z], axis=-1)

# %%
vor = Voronoi(points)

# %%
vor.vertices
# Out:
# array([[ 1.38604184, 13.2830856 , -1.92580827],
#        [ 0.93622577,  1.3519561 , -0.99897021],
#        [ 0.91157823,  1.11801205, -0.95894409],
#        ...,
#        [ 0.25252982, -0.56831835,  0.73107969],
#        [ 0.23816027, -0.55977943,  0.7152258 ],
#        [ 0.23841607, -0.56183277,  0.71592312]], shape=(636730, 3))

# %%
vor.ridge_points
# Out:
# array([[32648, 32626],
#        [32648, 32649],
#        [32648, 32647],
#        ...,
#        [ 6375,  5739],
#        [ 6375,  6371],
#        [ 6371,  5739]], shape=(736862, 2), dtype=int32)

# %%
len(vor.ridge_vertices)
# Out:
# 736862

# %%
len(vor.regions)
# Out:
# 100001
