# %%
import numpy as np
import unyt as u
import richio
import dev
import matplotlib.pyplot as plt

# %%
path = "/data1/projects/pi-rossiem/TDE_data/R0.47M0.5BH10000beta1S60n1.5ComptonHiResNewAMR/snap_151"
snap = richio.load(path)

# %%
Trad = (snap.Erad * snap.density / u.a) ** (1 / 4)

# %%
snap.plots.slice(data=Trad, res=512, box_size=[-50, -50, 50, 50], cmap="inferno")
plt.show()

# %%
snap.plots.slice(
    data="temperature",
    res=512,
    box_size=[-50, -50, 50, 50],
    cmap="inferno",
    vmin=4,
    vmax=6.5,
)
plt.show()
